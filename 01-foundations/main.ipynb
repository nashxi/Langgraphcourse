# %% [markdown]
# # Employee Overall Performance

# %% [markdown]
# ### Importing Packages

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
# ----> 4 from sklearn.preprocessing import OrdinalEncoder
#       5 from sklearn.preprocessing import StandardScaler
#       6 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# ### Exploratory Data Anlysis (EDA)
# - Merging Dataset
# - Describe Dataset
# - Information Dataset
# - N-Unique values in Dataset
# - Value counts in Dataset
# - Null Values in Dataset
# - Correlations of numerical dtypes
# - Checking for the outliers
# - Splitting in Features and label

# %% [markdown]
# ### Loading Dataset

# %%
demographic = pd.read_csv('demographic_detail.csv')
roster_with_score = pd.read_csv("roster_with_score.csv")
df = pd.merge(roster_with_score,demographic,on='employee_id')
df = df.drop(['Unnamed: 0_x','Unnamed: 0_y','first','last','employee_id'],axis=1)

# %% [markdown]
# ### Describe Dataset

# %%
df.describe()
# Out:
#        manager_id   tenure_id   alignment  development  enablement  \
# count  380.000000  381.000000  381.000000   381.000000  381.000000
# mean   373.263158    2.181102    0.780402     0.671391    0.781627
# std    227.816779    1.197040    0.085913     0.100472    0.121302
# min     11.000000    0.000000    0.533333     0.333333    0.333333
# 25%    183.000000    2.000000    0.733333     0.600000    0.733333
# 50%    365.000000    2.000000    0.800000     0.666667    0.800000
# 75%    572.000000    3.000000    0.866667     0.733333    0.866667
# max    756.000000    4.000000    1.000000     0.933333    1.000000
#
#        engagement  leadership     overall  year_of_birth  time_on_the_job
# count  381.000000  381.000000  381.000000     381.000000       381.000000
# mean     0.794646    0.823447    0.770303    1981.671916        25.488189
# std      0.069348    0.126808    0.069176      11.250496        18.178298
# min      0.600000    0.333333    0.568000    1949.000000         0.000000
# 25%      0.760000    0.733333    0.736000    1976.000000        13.000000
# 50%      0.800000    0.866667    0.773333    1982.000000        20.000000
# 75%      0.840000    0.933333    0.813333    1989.000000        38.000000
# max      0.920000    1.000000    0.949333    2003.000000        72.000000

# %% [markdown]
# ### Information Dataset

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 381 entries, 0 to 380
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              381 non-null    str
#  1   manager_id         380 non-null    float64
#  2   function           381 non-null    str
#  3   department         381 non-null    str
#  4   location           381 non-null    str
#  5   age                381 non-null    str
#  6   sex                381 non-null    str
#  7   ethnicity          381 non-null    str
#  8   employment_status  381 non-null    str
#  9   tenure             381 non-null    str
#  10  tenure_id          381 non-null    int64
#  11  alignment          381 non-null    float64
#  12  development        381 non-null    float64
#  13  enablement         381 non-null    float64
#  14  engagement         381 non-null    float64
#  15  leadership         381 non-null    float64
#  16  overall            381 non-null    float64
#  17  year_of_birth      381 non-null    int64
#  18  time_on_the_job    381 non-null    int64
# dtypes: float64(7), int64(3), str(9)
# memory usage: 56.7 KB

# %% [markdown]
# ### N-Unique value in Dataset

# %%
df.select_dtypes(['object']).nunique()
# Out:
# C:\Users\nkone\AppData\Local\Temp\ipykernel_3244\4026662855.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.select_dtypes(['object']).nunique()
# title                59
# function              8
# department           36
# location              5
# age                   6
# sex                   2
# ethnicity             5
# employment_status     2
# tenure                5
# dtype: int64

# %%
df.select_dtypes(['int64','float64']).nunique()
# Out:
# manager_id          59
# tenure_id            5
# alignment           10
# development         12
# enablement          14
# engagement          11
# leadership          12
# overall            155
# year_of_birth       51
# time_on_the_job     71
# dtype: int64

# %% [markdown]
# ### Value counts In Dataset

# %%
df.value_counts()
# Out:
# title                     manager_id  function         department                        location           age      sex  ethnicity   employment_status  tenure                  tenure_id  alignment  development  enablement  engagement  leadership  overall   year_of_birth  time_on_the_job
# Administrative Assistant  343.0       CEO              Leadership                        Mountain View, CA  45 - 54  F    white       Full time          2 to less than 4 years  3          0.800000   0.933333     0.933333    0.80        0.866667    0.866667  1976           38                 1
# VP Engineering            343.0       CEO              Engineering                       Mountain View, CA  35 - 44  M    asian       Full time          4 to less than 6 years  4          0.933333   0.866667     1.000000    0.84        1.000000    0.928000  1983           70                 1
# Administrative Assistant  11.0        CEO              Engineering                       Mountain View, CA  45 - 54  F    hispanic    Full time          less than 6 months      0          0.733333   0.800000     0.666667    0.76        0.466667    0.685333  1970           4                  1
# Chief Technology Officer  343.0       CEO              Advanced Technology               Mountain View, CA  35 - 44  F    asian       Full time          1 to less than 2 years  2          0.933333   0.533333     0.733333    0.80        0.866667    0.773333  1977           20                 1
# Administrative Assistant  417.0       CEO              Advanced Technology               Mountain View, CA  25 - 34  F    asian       Full time          1 to less than 2 years  2          0.666667   0.733333     0.800000    0.76        0.800000    0.752000  1989           16                 1
#                                                                                                                                                                                                                                                                                                    ..
# Loan Officer              600.0       Loan Operations  VA Loans                          New York, NY       35 - 44  M    white       Part time          1 to less than 2 years  2          0.666667   0.666667     0.733333    0.80        0.866667    0.746667  1980           17                 1
# Senior Loan Officer       307.0       Loan Operations  South Lending                     Atlanta, GA        65+      F    hispanic    Full time          2 to less than 4 years  3          0.733333   0.600000     0.733333    0.76        0.733333    0.712000  1953           34                 1
# Loan Officer              183.0       Loan Operations  Midwest Lending                   Chicago, IL        25 - 34  F    mixed_race  Full time          2 to less than 4 years  3          0.800000   0.733333     0.733333    0.72        0.800000    0.757333  1992           45                 1
# Senior Underwriter        458.0       Finance & Admin  Underwriting                      Mountain View, CA  25 - 34  M    asian       Full time          4 to less than 6 years  4          0.866667   0.933333     1.000000    0.92        0.933333    0.930667  1988           71                 1
# Designer                  85.0        Product          User Experience / User Interface  New York, NY       35 - 44  F    white       Full time          2 to less than 4 years  3          0.866667   0.800000     0.800000    0.76        0.933333    0.832000  1981           40                 1
# Name: count, Length: 380, dtype: int64

# %% [markdown]
# ### Null Values in Dataset

# %%
df.isnull().sum()
# Out:
# title                0
# manager_id           1
# function             0
# department           0
# location             0
# age                  0
# sex                  0
# ethnicity            0
# employment_status    0
# tenure               0
# tenure_id            0
# alignment            0
# development          0
# enablement           0
# engagement           0
# leadership           0
# overall              0
# year_of_birth        0
# time_on_the_job      0
# dtype: int64

# %% [markdown]
# ### Correlations of numerical dtypes

# %%
df_numerical = df.select_dtypes(['float64','int64'])
numerical_corr_mat = df_numerical.corr()
plt.figure(figsize=(10,5))
sns.heatmap(numerical_corr_mat,annot=True)
plt.show()

# %% [markdown]
# ### Overall vs Engagement

# %%
sns.scatterplot(data=df_numerical,x='engagement',y='overall')
plt.title('Overall vs Engagement')
# Out:
# Text(0.5, 1.0, 'Overall vs Engagement')

# %% [markdown]
# ### Overall vs Leadership

# %%
sns.scatterplot(data=df_numerical,x='leadership',y='overall')
plt.title('Overall vs Leadership')
# Out:
# Text(0.5, 1.0, 'Overall vs Leadership')

# %%
sns.regplot(data=df_numerical,x='leadership',y='overall')
plt.title('Overall vs Leadership')
# Out:
# Text(0.5, 1.0, 'Overall vs Leadership')

# %% [markdown]
# ### Checking for the Outliers

# %%
plt.figure(figsize=(15,5))
df_numerical.boxplot()
plt.show()

# %% [markdown]
# ### Splitting in Features and Label

# %%
X_features = df.copy()
y_label = df[['overall']]

# %% [markdown]
# ###  Data Preprocessing
# - Data Encoding
# - Data Standardization
# - Feature and Label Prepared
# - Train and Test split

# %% [markdown]
# ### Data Encoding

# %%
encoder = OrdinalEncoder()
X_features_encoded = encoder.fit_transform(X_features)

# %% [markdown]
# ### Data Standardization

# %%
scaler  = StandardScaler()
X_features_scaled = scaler.fit_transform(X_features_encoded)

# %% [markdown]
# ### Feature and Label Prepared

# %%
X_prepared = pd.DataFrame(X_features_scaled,columns=X_features.columns)
y_prepared = y_label.copy()

# %% [markdown]
# ### Train and Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_prepared,y_prepared,test_size=0.2,random_state=42)
print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (304, 19) (77, 19)
# (304, 1) (77, 1)

# %% [markdown]
# ### `NOTE:` Data Preprocessing for Employee Satisfaction dataset has prepraed for End to End Machine learning project visit: www.github.com/itechdp
