# %% [markdown]
# Matplotlib Basics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5,11)
x
y = x **2
y

# %%
plt.plot(x,y)
plt.show
plt.title("Hello World")
plt.xlabel("X axis")
plt.ylabel("Y axis")

# %% [markdown]
# Subplots in matplotlibs

# %%
plt.subplot(2,2,1)
plt.plot(y,x)
plt.subplot(2,2,2)
plt.plot(x,y)
plt.subplot(2,2,3)
plt.plot(x **2,x **2)
plt.subplot(2,2,4)
plt.plot(x,y)

# %% [markdown]
# Object Oriented Way

# %%
fig = plt.figure(figsize=(20,8),dpi = 100)
axes1 = fig.add_axes([0.1,0.1,1,1])
axes1.plot(x,y)
axes2 = fig.add_axes([0.3,0.4,.3,.3])
axes2.plot(x,y)

# %% [markdown]
# Type of Plots

# %%
plt.scatter(x,y)

# %%
plt.hist(x)

# %%
plt.boxplot(x)

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)
plt.savefig("Basic plot.png")

# %% [markdown]
# Working with Images

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread('image.jpeg')
plt.imshow(img)
plt.axis('off')

# %% [markdown]
# Optional Designing

# %%
plt.plot(x,y,color ="black")

# %% [markdown]
# Distribution plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("tips")
df

# %%
df['size'].unique()

# %% [markdown]
# Displot/Histplot

# %%
sns.histplot(df['total_bill'],bins = 20,kde = True)

# %%
plt.subplot(1,2,1)
sns.histplot(df['total_bill'],bins = 20, kde = True)
plt.subplot(1,2,2)
sns.histplot(df['tip'],bins = 20, kde = True)

# %% [markdown]
# Joint plot

# %%
sns.jointplot(data = df ,x = "total_bill", y = "tip" , kind = "scatter" )

# %%
sns.jointplot(data = df , x = "total_bill", y = "tip", kind = "reg")

# %% [markdown]
# Pair Plot

# %%
sns.pairplot(df, hue = "sex", palette = "rainbow")

# %% [markdown]
# Rug Plot

# %%
sns.rugplot(df,x = "tip")

# %% [markdown]
# Categorical Data Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("tips")
df

# %% [markdown]
# Count Plot

# %%
sns.countplot(x = df['sex'],hue = df['smoker'])

# %% [markdown]
# Bar Plot

# %%
import numpy as np
sns.barplot(x = df['sex'], y = df ['tip'],estimator =np.sum)

# %% [markdown]
# Box Plot

# %%
sns.boxplot(x = 'tip',y = 'day',data = df)

# %% [markdown]
# Violin Plot

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = df)

# %% [markdown]
# Strip Plot

# %%
sns.stripplot(x = 'day', y = 'total_bill', data = df)

# %% [markdown]
# Swarm Plot

# %%
sns.swarmplot(x = 'day', y = 'total_bill', data = df)

# %% [markdown]
# Violin plot and swarm plot dono ek sath show krna ha mujeh

# %%
sns.violinplot(x = 'tip', y = 'day', data = df)
sns.swarmplot(x = 'tip', y = 'day', data = df)

# %% [markdown]
# Matrix Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Heat Map (phele ismai dataset load krege)

# %%
tips = sns.load_dataset('tips')
tips

# %%
flights = sns.load_dataset('flights')
flights

# %%
tipscorr = tips[['total_bill', 'tip','size']]
tipscorr

# %%
tipscorr.corr()

# %%
sns.heatmap(tipscorr.corr(),annot = True)

# %% [markdown]
# Cluster Map

# %%
sns.clustermap(tipscorr.corr())

# %% [markdown]
# Pivot Table Heat Map

# %%
pvtflight = flights.pivot_table(values = 'passengers', index = 'month', columns = 'year')
pvtflight

# %%
sns.heatmap(pvtflight)

# %% [markdown]
# Regression Plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset("tips")
tips

# %%
sns.regplot(x = 'total_bill', y = 'tip', data = tips)

# %% [markdown]
# ismai mainai lmplot ka use kiya ha jo ki multiple line ke leye use hota ha

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, hue = 'sex')

# %% [markdown]
# ismai mainai colour change kiya ha

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, hue = 'sex' , palette = 'coolwarm')

# %% [markdown]
# mujeh ab male and female ka dots wale ka size increase krna ha and feamle ko represent triangle ke shape sai krna ha

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, hue = 'sex', palette = 'coolwarm', markers = ['o','v'],scatter_kws = {'s':50})

# %% [markdown]
# Plotly and Cufflinks (Phele hum Plotly and Cufflinks ko install karege)

# %%
#!pip install plotly
#!pip install cufflinks

# %%
import seaborn as sns
import pandas as pd
import cufflinks as cf
from plotly.offline import iplot

# %%
#!python -m pip install cufflinks

# %%
#pip install cufflinks

# %%
tips = sns.load_dataset('tips')
tips

# %% [markdown]
# phele hum total bill sai ek line graph create karege

# %%
tips[['total_bill ']].iplot(kind='line')

# %%
tips.groupby('day')['tip'].mean().iplot(kind = 'bar')

# %% [markdown]
# Now, Here comes some Basic Question

# %% [markdown]
# 1. Which team won the most matches?

# %%
match_wins = df['match_winner'].value_counts()
sns.barplot(y = match_wins.index, x = match_wins.values,palette = 'viridis')
plt.title("Most match win by team")

# %% [markdown]
# 2. Toss Decision Trends

# %%
sns.countplot(x = df['toss_decision'],palette = 'rainbow')
plt.title("Toss Decision Trends")

# %% [markdown]
# 3. Toss Winner vs Match Winner

# %%
count = df[df['toss_winner']== df ['match_winner']]['match_id'].count()
percentage = (count *100)/df.shape[0]
percentage

# %% [markdown]
# 4. How do teams win?(Runs vs wickets)

# %%
sns.countplot(x = df['won_by'],palette = 'rainbow')
plt.title("Won By")

# %% [markdown]
# 1. Most "Player of the match " Award

# %%
count = df['player_of_the_match'].value_counts().head(10)
count

# %%
sns.barplot(x = count.values,y = count.index,palette = 'mako')
plt.title("Top 10 players with man of thr match")

# %% [markdown]
# 2. Two Top Scorers

# %%
high = df.groupby('top_scorer')['highscore'].sum().sort_values(ascending = False).head(2)
high

# %%
high.plot(kind = 'barh')

# %% [markdown]
# 3. 10 Best Bowling Figures

# %%
df['highest_wickets'] = df['best_bowling_figure'].apply(lambda x:x.split('--')[0])
df['highest_wickets'] = df['highest_wickets'].astype(int)
top_bowlers = df.groupby('best_bowling') ['highest_wickets'].sum().sort_values(ascending = False).head(10)
top_bowlers.plot(kind = 'barh')

# %% [markdown]
# Venue Analysis

# %% [markdown]
# Most matches Played by venue

# %%
venue_count = df['venue'].value_counts()
venue_count

# %%
sns.barplot(y = venue_count.index,x = venue_count.values,palette = 'rainbow')

# %% [markdown]
# Custom Questions & Insights

# %% [markdown]
# 1. Who won the highest margin by runs ?

# %%
df[df['won_by']== 'Runs'].sort_values(by = 'margin',ascending = False).head(1)[['match_winner', 'margin']]

# %% [markdown]
# 2. Which player had the highest individual score ?

# %%
df[df['highscore'] == df['highscore'].max()][['top_scorer','highscore']]

# %% [markdown]
# 3. Which bowler had the best bowling figures?

# %%
df[df['highest_wickets'] == df['highest_wickets'].max()][['best_bowling','best_bowling_figure']]
